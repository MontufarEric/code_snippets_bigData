# %%
import os
from googleapiclient.discovery import build
import json
from kafka import KafkaProducer

# %%
api_key = os.environ.get("YOUTUBE_KEY")

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
users = ['andro4all', 'AndroideReview']

# %%
def getPlaylistId(userName):
    
    request = youtube.channels().list(
    part = 'contentDetails', 
    forUsername = userName
    )
    try: 
        user = request.execute()
        return(user['items'][0]['contentDetails']['relatedPlaylists']['uploads'])
    except: 
        print(f'ERROR READING VIDEOS FROM: {userName}')

# %%
def getVideos(playlistId, numOfVideos=50, page='CDIQAA' ):
    request = youtube.playlistItems().list(
    part = 'contentDetails', 
    playlistId = playlistId,
    maxResults = numOfVideos,
    pageToken = page)
    try:
        videos = request.execute()
        for i in videos['items']: 
            print(i['contentDetails']['videoId'])
        return [vid['contentDetails']['videoId'] for vid in videos['items']]
    except: 
        print(f"ERROR READING SONGS FROM PAGE {page}")
        return []

# %%
def getData(videoId):
    request = youtube.videos().list(
    part = 'statistics, snippet',
    id = videoId )
    try: 
        metadata = request.execute()
        stats = metadata['items'][0]['statistics']
        title = metadata['items'][0]['snippet']['title']
        date = metadata['items'][0]['snippet']['publishedAt']
        try: 
            tags = metadata['items'][0]['snippet']['tags']
        except:
            tags =[]
        return {'stats':stats, 'date': date, 'title': title, 'tags':tags}  
#         return(stats,date , title, tags)
    except:
        print("ERROR ------------------")
        return()

# %%
producer = KafkaProducer(bootstrap_servers=['localhost:9099'],
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
pl = map(lambda x: getPlaylistId(x), users)

# %%
vids = map(lambda x: getVideos(x,5), pl)

# %%
for col in vids: 
    for vid in col: 
        print(vid)
        print(json.dumps(getData(vid), indent=4))
        producer.send('test', json.dumps(vid))
        sleep(1)
# Out:
# RvqiTB-sQvo
# L5f539m-U20
# _Dv9XuAKjUw
# GerzygeyDhU
# _lBFluXl-rA
# RvqiTB-sQvo
# {
#     "stats": {
#         "viewCount": "56519",
#         "likeCount": "2465",
#         "dislikeCount": "72",
#         "favoriteCount": "0",
#         "commentCount": "132"
#     },
#     "date": "2020-06-30T21:05:25Z",
#     "title": "\u00a1VAYA CON MICROSOFT! Surface GO2 y Book3",
#     "tags": [
#         "Topesdegama",
#         "TDG",
#         "Terminal",
#         "Dispositivo",
#         "surface",
#         "surface go 2",
#         "port\u00e1til",
#         "notebook",
#         "pc",
#         "convertible",
#         "surface book 3",
#         "primeras impresiones",
#         "toma de contacto",
#         "hands on"
#     ]
# }
# L5f539m-U20
# {
#     "stats": {
#         "viewCount": "114820",
#         "likeCount": "4999",
#         "dislikeCount": "158",
#         "favoriteCount": "0",
#         "commentCount": "258"
#     },
#     "date": "2020-06-30T16:38:15Z",
#     "title": "SAMSUNG consigue LO NUNCA VISTO!!!",
#     "tags": [
#         "Topesdegama",
#         "TDG",
#         "Terminal",
#         "Dispositivo",
#         "tv",
#         "television",
#         "televisor",
#         "the sero",
#         "sero",
#         "la televisi\u00f3n que gira"
#     ]
# }
# _Dv9XuAKjUw
# {
#     "stats": {
#         "viewCount": "255217",
#         "likeCount": "9115",
#         "dislikeCount": "273",
#         "favoriteCount": "0",
#         "commentCount": "388"
#     },
#     "date": "2020-06-29T17:30:01Z",
#     "title": "Xiaomi se VUELVE LOCA \u00bfAcertar\u00e1?",
#     "tags": [
#         "Topesdegama",
#         "TDG",
#         "Terminal",
#         "Dispositivo",
#         "google pixel 5",
#         "xiaomi",
#         "quick charge",
#         "carga r\u00e1pida",
#         "100W",
#         "oneplus z",
#         "oneplus nord",
#         "oneplus lite",
#         "redmi 9a",
#         "galaxy note 20 ultra",
#         "galaxy fold 2",
#         "galaxy s20 fan edition",
#         "realme x3",
#         "ios 14",
#         "iphone 12",
#         "120 hz",
#         "realme buds q",
#         "noticias",
#         "news",
#         "galaxy watch 3",
#         "instagram",
#         "tiktok",
#         "harmony os"
#     ]
# }
# GerzygeyDhU
# {
#     "stats": {
#         "viewCount": "73499",
#         "likeCount": "2794",
#         "dislikeCount": "106",
#         "favoriteCount": "0",
#         "commentCount": "172"
#     },
#     "date": "2020-06-28T17:00:08Z",
#     "title": "Una de las mejores TV 4K CALIDAD / PRECIO!!!",
#     "tags": [
#         "Topesdegama",
#         "TDG",
#         "tv",
#         "television",
#         "televisor",
#         "tcl",
#         "TCL C71:",
#         "c71",
#         "tv c71 tcl"
#     ]
# }
# _lBFluXl-rA
# {
#     "stats": {
#         "viewCount": "185417",
#         "likeCount": "8442",
#         "dislikeCount": "187",
#         "favoriteCount": "0",
#         "commentCount": "949"
#     },
#     "date": "2020-06-27T17:30:01Z",
#     "title": "Mira este V\u00cdDEO antes DE COMPRAR un SMARTPHONE!!!!",
#     "tags": [
#         "Topesdegama",
#         "TDG",
#         "Terminal",
#         "Dispositivo",
#         "QUE SMARTPHONE COMPRAR",
#         "el recomendador",
#         "recomendaci\u00f3n smartphones",
#         "telefonos a comprar",
#         "los mejores telefonos",
#         "los mejores telefonos calidad precio",
#         "xiaomi",
#         "realme",
#         "samsung",
#         "apple"
#     ]
# }
# GzP9yG9RiSc
# TqfOtKYaXBA
# NnHxLY6T5tI
# Zq0XOEcxXjM
# yjS7-KqcIpY
# GzP9yG9RiSc
# {
#     "stats": {
#         "viewCount": "337386",
#         "likeCount": "34203",
#         "dislikeCount": "393",
#         "favoriteCount": "0",
#         "commentCount": "3920"
#     },
#     "date": "2020-04-02T18:11:36Z",
#     "title": "[ VIDEO EPICO ] - \u00bfPor qu\u00e9 el Galaxy Note 3 era un ADELANTADO A SU \u00c9POCA?",
#     "tags": [
#         "galaxy note 3",
#         "proandroid",
#         "pro android",
#         "review",
#         "mejor telefono",
#         "historia",
#         "video epico",
#         "samsung galaxy note 3"
#     ]
# }
# TqfOtKYaXBA
# {
#     "stats": {
#         "viewCount": "520965",
#         "likeCount": "21252",
#         "dislikeCount": "707",
#         "favoriteCount": "0",
#         "commentCount": "4165"
#     },
#     "date": "2020-04-01T16:58:40Z",
#     "title": "Como CONVERTIR tu Android en iPhone!!!!! EL TUTORIAL",
#     "tags": [
#         "android iphone",
#         "convertir",
#         "android",
#         "iphone",
#         "ios",
#         "iPhone 11",
#         "iOS 13",
#         "tutorial",
#         "pro android",
#         "proandroid",
#         "como convertir android",
#         "personalizar",
#         "personalizacion",
#         "launcher",
#         "control center",
#         "wallpaper"
#     ]
# }
# NnHxLY6T5tI
# {
#     "stats": {
#         "viewCount": "379458",
#         "likeCount": "21697",
#         "dislikeCount": "270",
#         "favoriteCount": "0",
#         "commentCount": "1926"
#     },
#     "date": "2020-03-31T17:54:39Z",
#     "title": "Realme 6, REVIEW y UNBOXING en espa\u00f1ol",
#     "tags": [
#         "realme 6",
#         "espa\u00f1ol",
#         "review",
#         "unboxing",
#         "analisis",
#         "vs mi9t",
#         "vs redmi note 9s",
#         "realme 6 vs xiaomi",
#         "pro android",
#         "proandroid",
#         "relame 6"
#     ]
# }
# Zq0XOEcxXjM
# {
#     "stats": {
#         "viewCount": "1184376",
#         "likeCount": "32407",
#         "dislikeCount": "1984",
#         "favoriteCount": "0",
#         "commentCount": "1944"
#     },
#     "date": "2020-03-30T18:51:44Z",
#     "title": "TOP 7 Mejores JUEGOS Android 2020 GRATIS - Nuevos Online y Offline",
#     "tags": [
#         "juegos android",
#         "mejores juegos",
#         "android",
#         "gratis",
#         "nuevos",
#         "2020",
#         "2021",
#         "online",
#         "offline",
#         "jeugos",
#         "celular",
#         "xiaomi",
#         "pro android",
#         "top juegos"
#     ]
# }
# yjS7-KqcIpY
# {
#     "stats": {
#         "viewCount": "297857",
#         "likeCount": "19394",
#         "dislikeCount": "196",
#         "favoriteCount": "0",
#         "commentCount": "1962"
#     },
#     "date": "2020-03-29T18:47:51Z",
#     "title": "Red Magic 5G, REVIEW en espa\u00f1ol - Lo Bueno y lo Malo!",
#     "tags": [
#         "red magic 5g",
#         "redmagic 5g",
#         "review",
#         "analisis",
#         "espa\u00f1ol",
#         "unboxing",
#         "gaming",
#         "telefono",
#         "precio",
#         "comprar",
#         "rendimiento",
#         "juegos",
#         "pro android"
#     ]
# }
